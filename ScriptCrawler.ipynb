# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
import re

import random
import urllib.request
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
EPISODE_INFO_DF = DataFrame(columns=('Season', 'EpisodeNo', 'Title', 'AirDate', 'Writers', 'Director', 'SEID'))
SCRIPT_DF = DataFrame(columns=('SEID', 'Character', 'Dialogue'))
BASE_URL = 'http://www.seinology.com/scripts/script-' 
EPISODE_NUMBERS = (
    list(map(_format_num, range(1, 82))) +

    # Double episode
    ['82and83'] +

    list(map(_format_num, range(84, 100))) +

    # Skip the clip show "100and101".

    list(map(_format_num, range(102, 177))) +

    # Skip the clip show "177and178".

    # Double episode (Finale)
    ['179and180']
)

# %%
episode_info_df, script_df = main(EPISODE_NUMBERS, BASE_URL, EPISODE_INFO_DF, SCRIPT_DF)
episode_info_df.to_csv('episode_info.csv', encoding='utf-8')
script_df.to_csv('scripts.csv', encoding='utf-8')

# %%
episode_info_df, script_df = main(EPISODE_NUMBERS, BASE_URL, EPISODE_INFO_DF, SCRIPT_DF)

# %%
EPISODE_INFO_DF = edf
SCRIPT_DF = sdf
EPISODE_NUMBERS = ['179and180']

# %%
script_df
# Out:
#         Character                                           Dialogue  \
# 0           JERRY  Do you know what this is all about? Do you kno...
# 1           JERRY  (pointing at Georges shirt) See, to me, that b...
# 2          GEORGE                                   Are you through?
# 3           JERRY             You do of course try on, when you buy?
# 4          GEORGE  Yes, it was purple, I liked it, I dont actuall...
# 5           JERRY                               Oh, you dont recall?
# 6          GEORGE  (on an imaginary microphone) Uh, no, not at th...
# 7           JERRY  Well, senator, Id just like to know, what you ...
# 8          CLAIRE                        Mr. Seinfeld. Mr. Costanza.
# 9          GEORGE  Are, are you sure this is decaf? Wheres the or...
# 10         CLAIRE  Its missing, I have to do it in my head decaf ...
# 11          JERRY  Can you relax, its a cup of coffee. Claire is ...
# 12         CLAIRE  Trust me George. No one has any interest in se...
# 13         GEORGE  How come youre not doin the second show tomorrow?
# 14          JERRY     Well, theres this uh, woman might be comin in.
# 15         GEORGE  Wait a second, wait a second, what coming in, ...
# 16          JERRY  I told you about Laura, the girl I met in Mich...
# 17         GEORGE                                     No, you didnt!
# 18          JERRY  I thought I told you about it, yes, she teache...
# 19         GEORGE                                                Ha.
# 20          JERRY  (looks in the creamer) Theres no milk in here,...
# 21         GEORGE  Wait wait wait, what is she... (takes the milk...
# 22          JERRY  Oh, shes really great. I mean, shes got like a...
# 23         GEORGE       (smiling) So, you know, what, what happened?
# 24          JERRY  Oh, nothing happened, you know, but is was great.
# 25         GEORGE                Oh, nothing happened, but it was...
# 26          JERRY                                              Yeah.
# 27         GEORGE                                     This is great!
# 28          JERRY                                              Yeah.
# 29         GEORGE  So, you know, she calls and says she wants to ...
# ...           ...                                                ...
# 54586       FRANK  We gotta get out of here. We want to beat the ...
# 54587       SIDRA                         Come on, Jackie. Let's go.
# 54588       JERRY                                              What?
# 54589      CHILES  Oh, and by the way, they're real, and they're ...
# 54590       JERRY  Well, it's only a year. That's not so bad. We'...
# 54591      KRAMER  Could be fun. Don't have to worry about your m...
# 54592      ELAINE           Why don't you just blow it out your a...
# 54593      ELAINE  If I call Jill from prison, do you think that ...
# 54594       JERRY                                              Sure.
# 54595      ELAINE  Cause you only get one call. The prison call i...
# 54596       JERRY         I think that would be a very nice gesture.
# 54597      KRAMER  I got it - it's out! How about that, huh? Oh, ...
# 54598       JERRY  See now, to me, that button is in the worst po...
# 54599      GEORGE                                            Really?
# 54600       JERRY  Oh yeah. The second button is the key button. ...
# 54601      GEORGE           Haven't we had this conversation before?
# 54602       JERRY                                         You think?
# 54603      GEORGE                                   I think we have.
# 54604       JERRY                               Yeah, maybe we have.
# 54605       JERRY  So what is the deal with the yard? I mean when...
# 54606  PRISONER 1                                              I am.
# 54607       JERRY  I'll talk slower. I'm kidding - I love Cellblo...
# 54608  PRISONER 2                                        Murder one.
# 54609       JERRY  Murder one? Oooooo, watch out everybody. Bette...
# 54610  PRISONER 3                                  Grand theft auto.
# 54611       JERRY    Grand theft auto - don't steal any of my jokes.
# 54612  PRISONER 3                      You suck - I'm gonna cut you.
# 54613       JERRY  Hey, I don't come down to where you work, and ...
# 54614       GUARD   Alright, Seinfeld, that's it. Let's go. Come on.
# 54615       JERRY  Alright, hey, you've been great! See you in th...
#
#        EpisodeNo    SEID  Season
# 0            1.0  S01E01     1.0
# 1            1.0  S01E01     1.0
# 2            1.0  S01E01     1.0
# 3            1.0  S01E01     1.0
# 4            1.0  S01E01     1.0
# 5            1.0  S01E01     1.0
# 6            1.0  S01E01     1.0
# 7            1.0  S01E01     1.0
# 8            1.0  S01E01     1.0
# 9            1.0  S01E01     1.0
# 10           1.0  S01E01     1.0
# 11           1.0  S01E01     1.0
# 12           1.0  S01E01     1.0
# 13           1.0  S01E01     1.0
# 14           1.0  S01E01     1.0
# 15           1.0  S01E01     1.0
# 16           1.0  S01E01     1.0
# 17           1.0  S01E01     1.0
# 18           1.0  S01E01     1.0
# 19           1.0  S01E01     1.0
# 20           1.0  S01E01     1.0
# 21           1.0  S01E01     1.0
# 22           1.0  S01E01     1.0
# 23           1.0  S01E01     1.0
# 24           1.0  S01E01     1.0
# 25           1.0  S01E01     1.0
# 26           1.0  S01E01     1.0
# 27           1.0  S01E01     1.0
# 28           1.0  S01E01     1.0
# 29           1.0  S01E01     1.0
# ...          ...     ...     ...
# 54586       23.0  S09E23     9.0
# 54587       23.0  S09E23     9.0
# 54588       23.0  S09E23     9.0
# 54589       23.0  S09E23     9.0
# 54590       23.0  S09E23     9.0
# 54591       23.0  S09E23     9.0
# 54592       23.0  S09E23     9.0
# 54593       23.0  S09E23     9.0
# 54594       23.0  S09E23     9.0
# 54595       23.0  S09E23     9.0
# 54596       23.0  S09E23     9.0
# 54597       23.0  S09E23     9.0
# 54598       23.0  S09E23     9.0
# 54599       23.0  S09E23     9.0
# 54600       23.0  S09E23     9.0
# 54601       23.0  S09E23     9.0
# 54602       23.0  S09E23     9.0
# 54603       23.0  S09E23     9.0
# 54604       23.0  S09E23     9.0
# 54605       23.0  S09E23     9.0
# 54606       23.0  S09E23     9.0
# 54607       23.0  S09E23     9.0
# 54608       23.0  S09E23     9.0
# 54609       23.0  S09E23     9.0
# 54610       23.0  S09E23     9.0
# 54611       23.0  S09E23     9.0
# 54612       23.0  S09E23     9.0
# 54613       23.0  S09E23     9.0
# 54614       23.0  S09E23     9.0
# 54615       23.0  S09E23     9.0
#
# [54616 rows x 5 columns]

# %%
# episode_info_df, script_df = main(EPISODE_NUMBERS, BASE_URL, EPISODE_INFO_DF, SCRIPT_DF)
edf = episode_info_df
edf = edf[edf.SEID != 'S09E23']

# %%
edf
# Out:
#      Season  EpisodeNo                                      Title  \
# 0       1.0        1.0                        Good News, Bad News
# 1       1.0        1.0                               The Stakeout
# 2       1.0        2.0                                The Robbery
# 3       1.0        3.0                             Male Unbonding
# 4       1.0        4.0                              The Stock Tip
# 5       2.0        1.0                          The Ex-Girlfriend
# 6       2.0        2.0                            The Pony Remark
# 7       2.0        3.0                                 The Jacket
# 8       2.0        4.0                          The Phone Message
# 9       2.0        5.0                              The Apartment
# 10      2.0        6.0                                 The Statue
# 11      2.0        7.0                                The Revenge
# 12      2.0        8.0                           The Heart Attack
# 13      2.0        9.0                                   The Deal
# 14      2.0       10.0                            The Baby Shower
# 15      2.0       11.0                     The Chinese Restaurant
# 16      2.0       12.0                                 The Busboy
# 17      3.0        1.0                                   The Note
# 18      3.0        2.0                                  The Truth
# 19      3.0        3.0                                    The Pen
# 20      3.0        4.0                                    The Dog
# 21      3.0        5.0                                The Library
# 22      3.0        6.0                         The Parking Garage
# 23      3.0        7.0                                   The Cafe
# 24      3.0        8.0                                   The Tape
# 25      3.0        9.0                               The Nose Job
# 26      3.0       10.0                               The Stranded
# 27      3.0       11.0                         The Alternate Side
# 28      3.0       12.0                                The Red Dot
# 29      3.0       13.0                                 The Subway
# ..      ...        ...                                        ...
# 143     8.0       13.0                               The Comeback
# 144     8.0       14.0                         The Van Buren Boys
# 145     8.0       15.0                                  The Susie
# 146     8.0       16.0                                The Pothole
# 147     8.0       17.0                        The English Patient
# 148     8.0       18.0                                    The Nap
# 149     8.0       19.0                              The Yada Yada
# 150     8.0       20.0                             The Millennium
# 151     8.0       21.0                            The Muffin Tops
# 152     8.0       22.0                       The Summer of George
# 153     9.0        1.0                           The Butter Shave
# 154     9.0        2.0                                  The Voice
# 155     9.0        3.0                           The Serenity Now
# 156     9.0        4.0                                  The Blood
# 157     9.0        5.0                              The Junk Mail
# 158     9.0        6.0                      The Merv Griffin Show
# 159     9.0        7.0                                 The Slicer
# 160     9.0        8.0                               The Betrayal
# 161     9.0        9.0                                The Apology
# 162     9.0       10.0                                 The Strike
# 163     9.0       11.0                             The Dealership
# 164     9.0       12.0  The Reverse Peephole (a.k.a. The Man Fur)
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
sdf = script_df
sdf = sdf[sdf.SEID != 'S09E23']

# %%
sdf
# Out:
#          Character                                           Dialogue  \
# 0            JERRY  Do you know what this is all about? Do you kno...
# 1            JERRY  (pointing at Georges shirt) See, to me, that b...
# 2           GEORGE                                   Are you through?
# 3            JERRY             You do of course try on, when you buy?
# 4           GEORGE  Yes, it was purple, I liked it, I dont actuall...
# 5            JERRY                               Oh, you dont recall?
# 6           GEORGE  (on an imaginary microphone) Uh, no, not at th...
# 7            JERRY  Well, senator, Id just like to know, what you ...
# 8           CLAIRE                        Mr. Seinfeld. Mr. Costanza.
# 9           GEORGE  Are, are you sure this is decaf? Wheres the or...
# 10          CLAIRE  Its missing, I have to do it in my head decaf ...
# 11           JERRY  Can you relax, its a cup of coffee. Claire is ...
# 12          CLAIRE  Trust me George. No one has any interest in se...
# 13          GEORGE  How come youre not doin the second show tomorrow?
# 14           JERRY     Well, theres this uh, woman might be comin in.
# 15          GEORGE  Wait a second, wait a second, what coming in, ...
# 16           JERRY  I told you about Laura, the girl I met in Mich...
# 17          GEORGE                                     No, you didnt!
# 18           JERRY  I thought I told you about it, yes, she teache...
# 19          GEORGE                                                Ha.
# 20           JERRY  (looks in the creamer) Theres no milk in here,...
# 21          GEORGE  Wait wait wait, what is she... (takes the milk...
# 22           JERRY  Oh, shes really great. I mean, shes got like a...
# 23          GEORGE       (smiling) So, you know, what, what happened?
# 24           JERRY  Oh, nothing happened, you know, but is was great.
# 25          GEORGE                Oh, nothing happened, but it was...
# 26           JERRY                                              Yeah.
# 27          GEORGE                                     This is great!
# 28           JERRY                                              Yeah.
# 29          GEORGE  So, you know, she calls and says she wants to ...
# ...            ...                                                ...
# 53873        JERRY                           Mr. Vandelay, of course.
# 53874  SALES WOMAN                           You two know each other?
# 53875  SALES WOMAN                                   Mr. Pennypacker!
# 53876       KRAMER  Uh, yes, uh, I--I wanted to, uh, stop by and m...
# 53877  SALES WOMAN  Mr. Pennypacker, this is Mr. Vandelay, And you...
# 53878       KRAMER                                       Uh, Varnsen.
# 53879        JERRY                                       Pennypacker.
# 53880       KRAMER                                          Vandelay.
# 53881       GEORGE                              Pennypacker. Varnsen.
# 53882        JERRY  Vandelay. Wait a second. Mr. Pennypacker, if y...
# 53883       KRAMER                                       The factory?
# 53884        JERRY                                  The Saab factory?
# 53885       KRAMER                           Jerry, that's in Sweden.
# 53886        JERRY                                            My car!
# 53887       KRAMER  Well, you know, it's like this every day in Pu...
# 53888       GEORGE                              Jerry, the Mets lost.
# 53889        JERRY                                   I love a parade!
# 53890       GEORGE                  How do you suppose they did that?
# 53891       KRAMER  Well...there's no logical explanation. All rig...
# 53892        JERRY                           Well, what about my car?
# 53893       KRAMER              Well, Jerry, you can't deduct it now.
# 53894        JERRY                               Hey, there's Elaine.
# 53895       ELAINE                                               Hey.
# 53896        JERRY                      Well, you look, uh...relaxed.
# 53897       ELAINE  Well, it is Sunday night, and you know how I l...
# 53898        LAMAR  Hey, black Saab. Looks like that building cut ...
# 53899        JERRY                          Well, at least he didn't-
# 53900        LAMAR                                           Jackass!
# 53901        JERRY                 Somebody remember where we parked.
# 53902       KRAMER          This was a fun day. It's nice to get out.
#
#        EpisodeNo    SEID  Season
# 0            1.0  S01E01     1.0
# 1            1.0  S01E01     1.0
# 2            1.0  S01E01     1.0
# 3            1.0  S01E01     1.0
# 4            1.0  S01E01     1.0
# 5            1.0  S01E01     1.0
# 6            1.0  S01E01     1.0
# 7            1.0  S01E01     1.0
# 8            1.0  S01E01     1.0
# 9            1.0  S01E01     1.0
# 10           1.0  S01E01     1.0
# 11           1.0  S01E01     1.0
# 12           1.0  S01E01     1.0
# 13           1.0  S01E01     1.0
# 14           1.0  S01E01     1.0
# 15           1.0  S01E01     1.0
# 16           1.0  S01E01     1.0
# 17           1.0  S01E01     1.0
# 18           1.0  S01E01     1.0
# 19           1.0  S01E01     1.0
# 20           1.0  S01E01     1.0
# 21           1.0  S01E01     1.0
# 22           1.0  S01E01     1.0
# 23           1.0  S01E01     1.0
# 24           1.0  S01E01     1.0
# 25           1.0  S01E01     1.0
# 26           1.0  S01E01     1.0
# 27           1.0  S01E01     1.0
# 28           1.0  S01E01     1.0
# 29           1.0  S01E01     1.0
# ...          ...     ...     ...
# 53873       20.0  S09E20     9.0
# 53874       20.0  S09E20     9.0
# 53875       20.0  S09E20     9.0
# 53876       20.0  S09E20     9.0
# 53877       20.0  S09E20     9.0
# 53878       20.0  S09E20     9.0
# 53879       20.0  S09E20     9.0
# 53880       20.0  S09E20     9.0
# 53881       20.0  S09E20     9.0
# 53882       20.0  S09E20     9.0
# 53883       20.0  S09E20     9.0
# 53884       20.0  S09E20     9.0
# 53885       20.0  S09E20     9.0
# 53886       20.0  S09E20     9.0
# 53887       20.0  S09E20     9.0
# 53888       20.0  S09E20     9.0
# 53889       20.0  S09E20     9.0
# 53890       20.0  S09E20     9.0
# 53891       20.0  S09E20     9.0
# 53892       20.0  S09E20     9.0
# 53893       20.0  S09E20     9.0
# 53894       20.0  S09E20     9.0
# 53895       20.0  S09E20     9.0
# 53896       20.0  S09E20     9.0
# 53897       20.0  S09E20     9.0
# 53898       20.0  S09E20     9.0
# 53899       20.0  S09E20     9.0
# 53900       20.0  S09E20     9.0
# 53901       20.0  S09E20     9.0
# 53902       20.0  S09E20     9.0
#
# [53903 rows x 5 columns]

# %%
def _format_num(n):
    return '%02d' % n

# %%
def get_episode_soup(no, base_url):
    url = base_url + str(no) + '.shtml'
    source_code = requests.get(url)
    plain_text = source_code.text
    return plain_text

# %%
def parse_episode_info(html):
    """Return a dict with meta-info about the episode."""
    groups = re.search(r'pc: .*? season (\d+), episode (\d+)', html).groups()
    season_num = int(groups[0])
    episode_num = int(groups[1])

    title = re.search(r'Episode \d+(.*?) - (.*?)<', html).groups()[1]
    title = re.sub(r'[^\x00-\x7f]',r'', title)
    date = re.search(r'Broadcast date: (.*?)<', html).groups()[0]
    writers = re.search(r'Written [bB]y([:]|&nbsp;)? (.*?)<', html).groups()[1]
    writers = ', '.join(tuple([w.strip() for w in re.split(r',|&amp;', writers) if w]))
    director = re.search(r'Directed [bB]y (.*?)<', html).groups()[0]
    seid = 'S'+ str(_format_num(season_num)) + 'E' + str(_format_num(episode_num))

    return {'season_num': season_num, 'episode_num': episode_num, 
            'title': title, 'date': date, 'writers': writers, 
            'director': director, 'seid': seid}

# %%
def main(episode_nos, base_url, episode_info_df, script_df):
    for no in log_progress(episode_nos, every=1):
        html = get_episode_soup(no, base_url)
        html_split = re.split(r'={30}.*', html)
        header = html_split[0]
        content = html_split[1]
        episode_info = parse_episode_info(header)
        if str(no) == '179and180':
            content = html_split[2]
            episode_info['title'] = 'The Finale'
            episode_info['episode_no'] = 'The Finale'
        soup = BeautifulSoup(content)
        dialogues = list(filter(None, soup.find('body').text.replace('\t', '').split('\n')))
        temp1 = DataFrame([[
            episode_info['season_num'], 
            episode_info['episode_num'],
            episode_info['title'],
            episode_info['date'],
            episode_info['writers'],
            episode_info['director'],
            episode_info['seid'],
        ]], columns=('Season', 'EpisodeNo', 'Title', 'AirDate', 'Writers', 'Director', 'SEID'))
        for dialogue in dialogues:
            if len(dialogue.split(':')) <= 1:
                continue
            dialogue_split = dialogue.split(':')
            character = dialogue_split.pop(0)
            line = ''.join(dialogue_split).strip()
            line = re.sub(r'[^\x00-\x7f]',r'', line) 
            temp2 = DataFrame([[
                episode_info['season_num'], 
                episode_info['episode_num'], 
                episode_info['seid'], 
                character,
                line
            ]], columns=('Season', 'EpisodeNo', 'SEID', 'Character', 'Dialogue'))
            script_df = script_df.append(temp2, ignore_index = True)
        episode_info_df = episode_info_df.append(temp1, ignore_index = True)
        return episode_info_df, script_df

# %%
episode_info_df
# Out:
#      Season  EpisodeNo                                      Title  \
# 0       1.0        1.0                        Good News, Bad News
# 1       1.0        1.0                               The Stakeout
# 2       1.0        2.0                                The Robbery
# 3       1.0        3.0                             Male Unbonding
# 4       1.0        4.0                              The Stock Tip
# 5       2.0        1.0                          The Ex-Girlfriend
# 6       2.0        2.0                            The Pony Remark
# 7       2.0        3.0                                 The Jacket
# 8       2.0        4.0                          The Phone Message
# 9       2.0        5.0                              The Apartment
# 10      2.0        6.0                                 The Statue
# 11      2.0        7.0                                The Revenge
# 12      2.0        8.0                           The Heart Attack
# 13      2.0        9.0                                   The Deal
# 14      2.0       10.0                            The Baby Shower
# 15      2.0       11.0                     The Chinese Restaurant
# 16      2.0       12.0                                 The Busboy
# 17      3.0        1.0                                   The Note
# 18      3.0        2.0                                  The Truth
# 19      3.0        3.0                                    The Pen
# 20      3.0        4.0                                    The Dog
# 21      3.0        5.0                                The Library
# 22      3.0        6.0                         The Parking Garage
# 23      3.0        7.0                                   The Cafe
# 24      3.0        8.0                                   The Tape
# 25      3.0        9.0                               The Nose Job
# 26      3.0       10.0                               The Stranded
# 27      3.0       11.0                         The Alternate Side
# 28      3.0       12.0                                The Red Dot
# 29      3.0       13.0                                 The Subway
# ..      ...        ...                                        ...
# 144     8.0       14.0                         The Van Buren Boys
# 145     8.0       15.0                                  The Susie
# 146     8.0       16.0                                The Pothole
# 147     8.0       17.0                        The English Patient
# 148     8.0       18.0                                    The Nap
# 149     8.0       19.0                              The Yada Yada
# 150     8.0       20.0                             The Millennium
# 151     8.0       21.0                            The Muffin Tops
# 152     8.0       22.0                       The Summer of George
# 153     9.0        1.0                           The Butter Shave
# 154     9.0        2.0                                  The Voice
# 155     9.0        3.0                           The Serenity Now
# 156     9.0        4.0                                  The Blood
# 157     9.0        5.0                              The Junk Mail
# 158     9.0        6.0                      The Merv Griffin Show
# 159     9.0        7.0                                 The Slicer
# 160     9.0        8.0                               The Betrayal
# 161     9.0        9.0                                The Apology
# 162     9.0       10.0                                 The Strike
# 163     9.0       11.0                             The Dealership
# 164     9.0       12.0  The Reverse Peephole (a.k.a. The Man Fur)
# 165     9.0       13.0                                The Cartoon
# 166     9.0       14.0                              The Strongbox
# 167     9.0       15.0                                 The Wizard
# 168     9.0       16.0                                The Burning
# 169     9.0       17.0                              The Bookstore
# 170     9.0       18.0                                The Frogger
# 171     9.0       19.0                                   The Maid
# 172     9.0       20.0                       The Puerto Rican Day
# 173     9.0       23.0                             The Finale (1)
#
#                 AirDate                                            Writers  \
# 0          July 5, 1989                        Larry David, Jerry Seinfeld
# 1          May 31, 1990                        Larry David, Jerry Seinfeld
# 2          June 7, 1990                                       Matt Goldman
# 3         June 14, 1990                        Larry David, Jerry Seinfeld
# 4         June 21, 1990                        Larry David, Jerry Seinfeld
# 5      January 16, 1991                        Larry David, Jerry Seinfeld
# 6      January 30, 1991                        Larry David, Jerry Seinfeld
# 7      February 6, 1991                        Larry David, Jerry Seinfeld
# 8     February 13, 1991                        Larry David, Jerry Seinfeld
# 9         April 4, 1991                                      Peter Mehlman
# 10       April 11, 1991                                        Larry David
# 11       April 18, 1991                                        Larry David
# 12       April 25, 1991                                      Larry Charles
# 13          May 2, 1991                                      Larry Charles
# 14         May 16, 1991                                      Larry Charles
# 15         May 23, 1991                        Larry David, Jerry Seinfeld
# 16        June 26, 1991                        Larry David, Jerry Seinfeld
# 17   September 18, 1991                                        Larry David
# 18   September 25, 1991                                        Elaine Pope
# 19      October 2, 1991                                        Larry David
# 20      October 9, 1991                                        Larry David
# 21     October 16, 1991                                      Larry Charles
# 22     October 30, 1991                                        Larry David
# 23     November 6, 1991                                        Tom Leopold
# 24    November 13, 1991              Larry David and Bob Shaw, Don McEnery
# 25    November 20, 1991                                      Peter Mehlman
# 26    November 27, 1991       Larry David, Jerry Seinfeld and Matt Goldman
# 27     December 4, 1991                       Larry David and Bill Masters
# 28    December 11, 1991                                        Larry David
# 29      January 8, 1992                                        Larry David
# ..                  ...                                                ...
# 144    February 6, 1997                                        Darin Henry
# 145   February 13, 1997                                       David Mandel
# 146   February 20, 1997                    Steve O'Donnell and Dan O'Keefe
# 147      March 13, 1997                                        Steve Koren
# 158          Andy Ackerman  S09E06
# 159          Andy Ackerman  S09E07
# 160          Andy Ackerman  S09E08
# 161          Andy Ackerman  S09E09
# 162          Andy Ackerman  S09E10
# 163          Andy Ackerman  S09E11
# 164          Andy Ackerman  S09E12
# 165          Andy Ackerman  S09E13
# 166          Andy Ackerman  S09E14
# 167          Andy Ackerman  S09E15
# 168          Andy Ackerman  S09E16
# 169          Andy Ackerman  S09E17
# 170          Andy Ackerman  S09E18
# 171          Andy Ackerman  S09E19
# 172          Andy Ackerman  S09E20
# 173          Andy Ackerman  S09E23
#
# [174 rows x 7 columns]

# %%
script_df
# Out:
#             Character                                           Dialogue  \
# 0               JERRY  Do you know what this is all about? Do you kno...
# 1               JERRY  (pointing at Georges shirt) See, to me, that b...
# 2              GEORGE                                   Are you through?
# 3               JERRY             You do of course try on, when you buy?
# 4              GEORGE  Yes, it was purple, I liked it, I dont actuall...
# 5               JERRY                               Oh, you dont recall?
# 6              GEORGE  (on an imaginary microphone) Uh, no, not at th...
# 7               JERRY  Well, senator, Id just like to know, what you ...
# 8              CLAIRE                        Mr. Seinfeld. Mr. Costanza.
# 9              GEORGE  Are, are you sure this is decaf? Wheres the or...
# 10             CLAIRE  Its missing, I have to do it in my head decaf ...
# 11              JERRY  Can you relax, its a cup of coffee. Claire is ...
# 12             CLAIRE  Trust me George. No one has any interest in se...
# 13             GEORGE  How come youre not doin the second show tomorrow?
# 14              JERRY     Well, theres this uh, woman might be comin in.
# 15             GEORGE  Wait a second, wait a second, what coming in, ...
# 16              JERRY  I told you about Laura, the girl I met in Mich...
# 17             GEORGE                                     No, you didnt!
# 18              JERRY  I thought I told you about it, yes, she teache...
# 19             GEORGE                                                Ha.
# 20              JERRY  (looks in the creamer) Theres no milk in here,...
# 21             GEORGE  Wait wait wait, what is she... (takes the milk...
# 22              JERRY  Oh, shes really great. I mean, shes got like a...
# 23             GEORGE       (smiling) So, you know, what, what happened?
# 24              JERRY  Oh, nothing happened, you know, but is was great.
# 25             GEORGE                Oh, nothing happened, but it was...
# 26              JERRY                                              Yeah.
# 27             GEORGE                                     This is great!
# 28              JERRY                                              Yeah.
# 29             GEORGE  So, you know, she calls and says she wants to ...
# ...               ...                                                ...
# 53891          KRAMER  Well...there's no logical explanation. All rig...
# 53892           JERRY                           Well, what about my car?
# 53893          KRAMER              Well, Jerry, you can't deduct it now.
# 53894           JERRY                               Hey, there's Elaine.
# 53895          ELAINE                                               Hey.
# 53896           JERRY                      Well, you look, uh...relaxed.
# 53897          ELAINE  Well, it is Sunday night, and you know how I l...
# 53898           LAMAR  Hey, black Saab. Looks like that building cut ...
# 53899           JERRY                          Well, at least he didn't-
# 53900           LAMAR                                           Jackass!
# 53901           JERRY                 Somebody remember where we parked.
# 53902          KRAMER          This was a fun day. It's nice to get out.
# 53903              pc                           924 season 9, episode 24
# 53904  Broadcast date                                       May 14, 1998
# 53905        Regulars
# 53906     Guest Stars
# 53907              rc               Wayne Knight ................ Newman
# 53908              rc  Jerry Stiller ..................... Frank Cost...
# 53909              rc  Estelle Harris .................. Estelle Cost...
# 53910              rc    Liz Sheridan ................... Helen Seinfeld
# 53911              rc      Barney Martin ................ Morty Seinfeld
# 53912              rc             Ian Abercrombie ............. Mr. Pitt
# 53913              rc            Richard Fancy ................. Lippman
# 53914              rc            Richard Herd .................. Wilhelm
# 53915              rc         Steve Hytner ................. Kenny Bania
# 53916              rc        Len Lesser ...................... Uncle Leo
# 53917              rc  Phil Morris ....................... Jackie Chiles
# 53918              rc        John O'Hurley ................. J. Peterman
# 53919              rc            Patrick Warburton ......... David Puddy
# 53920              rc             Danny Woodburn ......... Mickey Abbott
#
#        EpisodeNo    SEID  Season
# 0            1.0  S01E01     1.0
# 1            1.0  S01E01     1.0
# 2            1.0  S01E01     1.0
# 3            1.0  S01E01     1.0
# 4            1.0  S01E01     1.0
# 5            1.0  S01E01     1.0
# 6            1.0  S01E01     1.0
# 7            1.0  S01E01     1.0
# 8            1.0  S01E01     1.0
# 9            1.0  S01E01     1.0
# 10           1.0  S01E01     1.0
# 11           1.0  S01E01     1.0
# 12           1.0  S01E01     1.0
# 13           1.0  S01E01     1.0
# 14           1.0  S01E01     1.0
# 15           1.0  S01E01     1.0
# 16           1.0  S01E01     1.0
# 17           1.0  S01E01     1.0
# 18           1.0  S01E01     1.0
# 19           1.0  S01E01     1.0
# 20           1.0  S01E01     1.0
# 21           1.0  S01E01     1.0
# 22           1.0  S01E01     1.0
# 23           1.0  S01E01     1.0
# 24           1.0  S01E01     1.0
# 25           1.0  S01E01     1.0
# 26           1.0  S01E01     1.0
# 27           1.0  S01E01     1.0
# 28           1.0  S01E01     1.0
# 29           1.0  S01E01     1.0
# ...          ...     ...     ...
# 53891       20.0  S09E20     9.0
# 53892       20.0  S09E20     9.0
# 53893       20.0  S09E20     9.0
# 53894       20.0  S09E20     9.0
# 53895       20.0  S09E20     9.0
# 53896       20.0  S09E20     9.0
# 53897       20.0  S09E20     9.0
# 53898       20.0  S09E20     9.0
# 53899       20.0  S09E20     9.0
# 53900       20.0  S09E20     9.0
# 53901       20.0  S09E20     9.0
# 53902       20.0  S09E20     9.0
# 53903       23.0  S09E23     9.0
# 53904       23.0  S09E23     9.0
# 53905       23.0  S09E23     9.0
# 53906       23.0  S09E23     9.0
# 53907       23.0  S09E23     9.0
# 53908       23.0  S09E23     9.0
# 53909       23.0  S09E23     9.0
# 53910       23.0  S09E23     9.0
# 53911       23.0  S09E23     9.0
# 53912       23.0  S09E23     9.0
# 53913       23.0  S09E23     9.0
# 53914       23.0  S09E23     9.0
# 53915       23.0  S09E23     9.0
# 53916       23.0  S09E23     9.0
# 53917       23.0  S09E23     9.0
# 53918       23.0  S09E23     9.0
# 53919       23.0  S09E23     9.0
# 53920       23.0  S09E23     9.0
#
# [53921 rows x 5 columns]
